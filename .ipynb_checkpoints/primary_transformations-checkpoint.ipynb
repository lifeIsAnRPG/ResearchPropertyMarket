# %%
import pandas as pd

# %%
flat_1room_sale = pd.read_csv('cian_parsing_result_sale_1_100_sankt-peterburg_03_Apr_2023.csv', encoding = 'windows-1251', sep = ';')

# %%
flat_1room_sale.loc[flat_1room_sale.link == 'https://spb.cian.ru/sale/flat/280819981/','total_meters'] = 36.81

# %%
flat_1room_sale['rooms_count'] = flat_1room_sale['rooms_count'].replace(-1, 1)

# %%
flat_2rooms_sale = pd.read_csv('cian_parsing_result_sale_1_100_sankt-peterburg_04_Apr_2023_2.csv', encoding = 'windows-1251', sep = ';')

# %%
flat_2rooms_sale['rooms_count'] = flat_2rooms_sale['rooms_count'].replace(-1,2)

# %%
flat_3rooms_sale = pd.read_csv('cian_parsing_result_sale_1_100_sankt-peterburg_04_Apr_2023_3.csv', encoding = 'windows-1251', sep = ';')

# %%
flat_3rooms_sale['rooms_count'] = flat_3rooms_sale['rooms_count'].replace(-1,3)

# %%
flat_4rooms_sale = pd.read_csv('cian_parsing_result_sale_1_100_sankt-peterburg_04_Apr_2023_4.csv', encoding = 'windows-1251', sep = ';')

# %%
flat_4rooms_sale['rooms_count'] = flat_4rooms_sale['rooms_count'].replace(-1,4)

# %%
flat_5rooms_sale = pd.read_csv('cian_parsing_result_sale_1_100_sankt-peterburg_04_Apr_2023_5.csv', encoding = 'windows-1251', sep = ';')

# %%
flat_5rooms_sale['rooms_count'] = flat_5rooms_sale['rooms_count'].replace(-1,5)

# %%
flat_studio_sale = pd.read_csv('cian_parsing_result_sale_1_100_sankt-peterburg_04_Apr_2023_studio.csv', encoding = 'windows-1251', sep = ';')

# %%
flat_studio_sale['rooms_count'] = 0.5
flat_studio_sale['rooms_count'].dtype
# Out:
# dtype('float64')

# %%
data = pd.concat([flat_1room_sale,flat_2rooms_sale,flat_3rooms_sale,flat_4rooms_sale,flat_5rooms_sale,flat_studio_sale])
data.sample(5)
# Out:
#                   author        author_type
# 399                СЕЗАН  real_estate_agent  \
# 997             Унистрой          developer
# 236         ГлавстройСПб          developer
# 814  Владис Северо-Запад  real_estate_agent
# 9          Группа Эталон          developer
#
#                                          link             city deal_type
# 399  https://spb.cian.ru/sale/flat/284757729/  Sankt-Peterburg      sale  \
# 997  https://spb.cian.ru/sale/flat/277296499/  Sankt-Peterburg      sale
# 236  https://spb.cian.ru/sale/flat/275297463/  Sankt-Peterburg      sale
# 814  https://spb.cian.ru/sale/flat/284247196/  Sankt-Peterburg      sale
# 9    https://spb.cian.ru/sale/flat/283802464/  Sankt-Peterburg      sale
#
#     accommodation_type  floor  floors_count  rooms_count  total_meters
# 399               flat      9             9          2.0         51.20  \
# 997               flat      2            10          3.0         98.20
# 236               flat     15            17          4.0         52.60
# 814               flat     17            20          0.5         22.00
# 9                 flat      6            10          2.0         64.87
#
#      price_per_m2     price  year_of_construction  living_meters
# 399        126953   6500000                  1968           31.1  \
# 997        309674  30410000                  2024           55.0
# 236        169000   8889400                  2023           27.0
# 814        150000   3300000                  2022           14.0
# 9          252460  16377107                  2023           24.0
#
#      kitchen_meters         phone           district           street
# 399             6.3  7.968190e+10  Krasnogvardejskij  Petra Smorodina  \
# 997            17.0  7.812213e+10  Krasnogvardejskij   Bol'shaja Ohta
# 236            14.0  7.812214e+10         Primorskij        Ivinskaja
# 814             3.0  7.911791e+10         Vyborgskij           Parnas
# 9              17.0  7.812213e+10        Kalininskij     Finljandskij
#
#           underground          residential_complex
# 399               NaN                          NaN
# 997  Novocherkasskaja                  Jupoint ZhK
# 236          Begovaja                    Juntolovo
# 814            Parnas  Kompleks apartamentov START
# 9         Vyborgskaja                        iLona

# %%
data.shape
# Out:
# (7118, 20)

# %%
data.to_csv('cian_data_sale.csv', sep = ';',index= False)

# %%
pd.read_csv('cian_data_sale.csv',sep=';')
# Out:
#                                    author        author_type
# 0     Петербургская Строительная Компания          developer  \
# 1     Петербургская Строительная Компания          developer
# 2                                  GloraX          developer
# 3                           Группа Эталон          developer
# 4                                  GloraX          developer
# ...                                   ...                ...
# 7113                                ДомИн  real_estate_agent
# 7114                          ID 85244212            unknown
# 7115                      Никита Лабецкий            realtor
# 7116               Константин Стародубцев            realtor
# 7117        CENTURY 21 Capital Petersburg  real_estate_agent
#
#                                           link             city deal_type
# 0     https://spb.cian.ru/sale/flat/284740225/  Sankt-Peterburg      sale  \
# 1     https://spb.cian.ru/sale/flat/280819981/  Sankt-Peterburg      sale
# 2     https://spb.cian.ru/sale/flat/279507591/  Sankt-Peterburg      sale
# 3     https://spb.cian.ru/sale/flat/285017335/  Sankt-Peterburg      sale
# 4     https://spb.cian.ru/sale/flat/279351916/  Sankt-Peterburg      sale
# ...                                        ...              ...       ...
# 7113  https://spb.cian.ru/sale/flat/285244128/  Sankt-Peterburg      sale
# 7114  https://spb.cian.ru/sale/flat/283138090/  Sankt-Peterburg      sale
# 7115  https://spb.cian.ru/sale/flat/273083309/  Sankt-Peterburg      sale
# 7116  https://spb.cian.ru/sale/flat/272558236/  Sankt-Peterburg      sale
# 7117  https://spb.cian.ru/sale/flat/285359807/  Sankt-Peterburg      sale
#
#      accommodation_type  floor  floors_count  rooms_count  total_meters
# 0                  flat      1             7          1.0         38.20  \
# 1                  flat     13            25          1.0         36.81
# 2                  flat      5            19          1.0         36.76
# 3                  flat     13            18          1.0         32.60
# 4                  flat     11            14          1.0         34.44
# ...                 ...    ...           ...          ...           ...
# 7113               flat     19            19          0.5         22.00
# 7114               flat      7            19          0.5         27.00
# 7115               flat      4            25          0.5         24.70
# 7116               flat     10            14          0.5         25.91
# 7117               flat      6            27          0.5         24.80
#
#       price_per_m2     price  year_of_construction  living_meters
# 0           419999  16044000                  2023           12.0  \
# 1            33201   6706674                  2024           10.0
# 2           265777   9769999                  2025           11.0
# 3           303116   9881582                  2022           21.0
# 4           322009  11089999                  2024           12.0
# ...            ...       ...                   ...            ...
# 7113        231818   5099999                  2017           -1.0
# 7114        168518   4550000                  2017           -1.0
# 7115        182186   4499999                  2021           15.0
# 7116        189116   4900000                  2022           -1.0
# 7117        181451   4500000                  2019           17.0
#
#       kitchen_meters         phone           district             street
# 0               12.0  7.812218e+10      Petrogradskij        Chkalovskoe  \
# 1               13.0  7.812218e+10         Primorskij          Kolomjagi
# 2               11.0  7.812213e+10   Vasileostrovskij            Morskoj
# 3               -1.0  7.812213e+10     Admiraltejskij       Izmajlovskoe
# 4               13.0  7.812213e+10  Krasnogvardejskij        Malaja Ohta
# ...              ...           ...                ...                ...
# 7113             1.0  7.905219e+10   Vasileostrovskij            Morskoj
# 7114            -1.0  7.981138e+10         Primorskij      Parashjutnaja
# 7115             4.0  7.981861e+10         Primorskij          Kolomjagi
# 7116            19.0  7.968187e+10         Primorskij       Ozero Dolgoe
# 7117            -1.0  7.981843e+10         Vyborgskij  Nikolaja Rubtsova
#
#                   underground                   residential_complex
# 0              Petrogradskaja                      Severnaja Korona
# 1     Prospekt Prosveschenija                            Frends ZhK
# 2                       Zenit  Gloraks Premium Vasileostrovskij ZhK
# 3           Moskovskie vorota                     Kvartal Galaktika
# 4                 Ladozhskaja                      Glorax Zanevskij
# ...                       ...                                   ...
# 7113              Primorskaja                                   NaN
# 7114   Komendantskij prospekt                              Graffiti
# 7115   Komendantskij prospekt                          Chistoe nebo
# 7116   Komendantskij prospekt                          Chistoe nebo
# 7117                   Parnas                      Severnaja dolina
#
# [7118 rows x 20 columns]

# %% [markdown]
# ## Москва

# %%
import cianparser

# %%
data = cianparser.parse(
    deal_type="sale", # "rent_long", "rent_short", "sale"
    accommodation_type="flat", # "flat", "room", "house", "house-part", "townhouse"
    location="Москва",
    rooms="studio", # "studio", 1, 2, 3, 4, 5
    start_page=1,
    end_page=100,
    is_saving_csv=True,
    is_latin=True,
    is_express_mode=False,
    is_by_homeowner=False,)
print(data[0])
# Out:
#                               Preparing to collect information from pages..
# The absolute path to the file:
# C:\Users\UserSasha\QualificationWork\cian_parsing_result_sale_1_100_moskva_09_Apr_2023_09_38_35_983652.csv
#
#
#
# The collection of information from the pages with list of announcements is completed
# Total number of parced announcements: 0. Average price: 0 rub
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[73], line 12
#       1 data = cianparser.parse(
#       2     deal_type="sale", # "rent_long", "rent_short", "sale"
#       3     accommodation_type="flat", # "flat", "room", "house", "house-part", "townhouse"
#    (...)
#      10     is_express_mode=False,
#      11     is_by_homeowner=False,)
# ---> 12 print(data[0])
#
# IndexError: list index out of range
