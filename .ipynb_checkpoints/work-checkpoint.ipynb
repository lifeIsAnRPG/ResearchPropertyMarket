# %%
import pandas as pd
import scipy.stats as stats
import cianparser # https://github.com/lenarsaitov/cianparser
import distance
from jellyfish import jaro_winkler
import seaborn as sns
import matplotlib.pyplot as plt

# %%
cianparser.parse(
    deal_type="sale", # "rent_long", "rent_short", "sale"
    accommodation_type="flat", # "flat", "room", "house", "house-part", "townhouse"
    location="Санкт-Петербург",
    rooms=2, # "studio"
    start_page=1,
    end_page=100,
    is_saving_csv=True,
    is_latin=True,
    is_express_mode=False,
    is_by_homeowner=False,)
# Out:
#                               Preparing to collect information from pages..
# The absolute path to the file:
# C:\Users\UserSasha\QualificationWork\cian_parsing_result_sale_1_100_sankt-peterburg_08_Apr_2023_16_03_00_049578.csv
#
#
#
# Exception: 500 Server Error: Internal Server Error for url: https://www.cian.ru/cat.php?engine_version=2&p=3&region=2&offer_type=flat&deal_type=sale&room2=1&with_neighbors=0
# The collection of information from the pages with ending parse on 3 page...
#
# Average price per day: 0 rub
#
#
# The collection of information from the pages with list of announcements is completed
# Total number of parced announcements: 0. Average price: 0 rub

# %%
data = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vTulT53cUzDGYyVXhek5ElnmIOoY1KV4NiQajXw0i3-U2DbFENz6ngPWBF16XRZnrgymcwguVk4_Yhc/pub?gid=351372992&single=true&output=csv')

# %% [markdown]
# ## Предобработка данных(квартиры на продажу в Санкт-Петербурге)

# %%
data.head()
# Out:
#                                 author author_type
# 0  Петербургская Строительная Компания   developer  \
# 1  Петербургская Строительная Компания   developer
# 2                               GloraX   developer
# 3                        Группа Эталон   developer
# 4                               GloraX   developer
#
#                                        link             city deal_type
# 0  https://spb.cian.ru/sale/flat/284740225/  Sankt-Peterburg      sale  \
# 1  https://spb.cian.ru/sale/flat/280819981/  Sankt-Peterburg      sale
# 2  https://spb.cian.ru/sale/flat/279507591/  Sankt-Peterburg      sale
# 3  https://spb.cian.ru/sale/flat/285017335/  Sankt-Peterburg      sale
# 4  https://spb.cian.ru/sale/flat/279351916/  Sankt-Peterburg      sale
#
#   accommodation_type  floor  floors_count  rooms_count  total_meters
# 0               flat      1             7          1.0         38.20  \
# 1               flat     13            25          1.0         36.81
# 2               flat      5            19          1.0         36.76
# 3               flat     13            18          1.0         32.60
# 4               flat     11            14          1.0         34.44
#
#    price_per_m2     price  year_of_construction  living_meters
# 0        419999  16044000                  2023           12.0  \
# 1         33201   6706674                  2024           10.0
# 2        265777   9769999                  2025           11.0
# 3        303116   9881582                  2022           21.0
# 4        322009  11089999                  2024           12.0
#
#    kitchen_meters         phone           district        street
# 0            12.0  7.812218e+10      Petrogradskij   Chkalovskoe  \
# 1            13.0  7.812218e+10         Primorskij     Kolomjagi
# 2            11.0  7.812213e+10   Vasileostrovskij       Morskoj
# 3            -1.0  7.812213e+10     Admiraltejskij  Izmajlovskoe
# 4            13.0  7.812213e+10  Krasnogvardejskij   Malaja Ohta
#
#                underground                   residential_complex
# 0           Petrogradskaja                      Severnaja Korona
# 1  Prospekt Prosveschenija                            Frends ZhK
# 2                    Zenit  Gloraks Premium Vasileostrovskij ZhK
# 3        Moskovskie vorota                     Kvartal Galaktika
# 4              Ladozhskaja                      Glorax Zanevskij

# %%
data.shape
# Out:
# (7118, 16)

# %%
data['flat_id'] = data['link'].str.extract('(\d+)')

# %%
data.drop('link', axis = 1,inplace = True)

# %%
data.drop(['accommodation_type','deal_type','city'],axis = 1,inplace = True)

# %%
n = len(data['author']) // 2
authors1 = data['author'][:n]
authors2 = data['author'][n:]
authors1= authors1.astype('str')
authors2= authors2.astype('str')

# %%
distances = authors1.apply(lambda x: authors2.apply(lambda y: jaro_winkler(x,y)))

# %%
data.head()
# Out:
#                                 author author_type  floor  floors_count
# 0  Петербургская Строительная Компания   developer      1             7  \
# 1  Петербургская Строительная Компания   developer     13            25
# 2                               GloraX   developer      5            19
# 3                        Группа Эталон   developer     13            18
# 4                               GloraX   developer     11            14
#
#    rooms_count  total_meters  price_per_m2     price  year_of_construction
# 0          1.0         38.20        419999  16044000                  2023  \
# 1          1.0         36.81         33201   6706674                  2024
# 2          1.0         36.76        265777   9769999                  2025
# 3          1.0         32.60        303116   9881582                  2022
# 4          1.0         34.44        322009  11089999                  2024
#
#    living_meters  kitchen_meters         phone           district
# 0           12.0            12.0  7.812218e+10      Petrogradskij  \
# 1           10.0            13.0  7.812218e+10         Primorskij
# 2           11.0            11.0  7.812213e+10   Vasileostrovskij
# 3           21.0            -1.0  7.812213e+10     Admiraltejskij
# 4           12.0            13.0  7.812213e+10  Krasnogvardejskij
#
#          street              underground
# 0   Chkalovskoe           Petrogradskaja  \
# 1     Kolomjagi  Prospekt Prosveschenija
# 2       Morskoj                    Zenit
# 3  Izmajlovskoe        Moskovskie vorota
# 4   Malaja Ohta              Ladozhskaja
#
#                     residential_complex    flat_id
# 0                      Severnaja Korona  284740225
# 1                            Frends ZhK  280819981
# 2  Gloraks Premium Vasileostrovskij ZhK  279507591
# 3                     Kvartal Galaktika  285017335
# 4                      Glorax Zanevskij  279351916

# %%
data.drop('phone', axis =1, inplace=True)

# %%
data_duplicated_indexes = data[data.duplicated() == True].index

# %%
data = data.drop(data_duplicated_indexes, axis =0)

# %%
data[['total_meters', 'price_per_m2','year_of_construction','living_meters','kitchen_meters']] = data[['total_meters', 'price_per_m2','year_of_construction','living_meters','kitchen_meters']].replace(-1.0, None)

# %%
data.head()
# Out:
#                                 author author_type  floor  floors_count
# 0  Петербургская Строительная Компания   developer      1             7  \
# 1  Петербургская Строительная Компания   developer     13            25
# 2                               GloraX   developer      5            19
# 3                        Группа Эталон   developer     13            18
# 4                               GloraX   developer     11            14
#
#    rooms_count total_meters  price_per_m2     price year_of_construction
# 0          1.0         38.2        419999  16044000                 2023  \
# 1          1.0        36.81         33201   6706674                 2024
# 2          1.0        36.76        265777   9769999                 2025
# 3          1.0         32.6        303116   9881582                 2022
# 4          1.0        34.44        322009  11089999                 2024
#
#   living_meters kitchen_meters           district        street
# 0          12.0           12.0      Petrogradskij   Chkalovskoe  \
# 1          10.0           13.0         Primorskij     Kolomjagi
# 2          11.0           11.0   Vasileostrovskij       Morskoj
# 3          21.0           None     Admiraltejskij  Izmajlovskoe
# 4          12.0           13.0  Krasnogvardejskij   Malaja Ohta
#
#                underground                   residential_complex    flat_id
# 0           Petrogradskaja                      Severnaja Korona  284740225
# 1  Prospekt Prosveschenija                            Frends ZhK  280819981
# 2                    Zenit  Gloraks Premium Vasileostrovskij ZhK  279507591
# 3        Moskovskie vorota                     Kvartal Galaktika  285017335
# 4              Ladozhskaja                      Glorax Zanevskij  279351916

# %%
data.isna().sum()
# Out:
# author                    22
# author_type               22
# floor                      0
# floors_count               0
# rooms_count                0
# total_meters               1
# price_per_m2               0
# price                      0
# year_of_construction     155
# living_meters            468
# kitchen_meters          1086
# district                   0
# street                   120
# underground              361
# residential_complex     2697
# flat_id                    0
# dtype: int64

# %%
data
# Out:
#                                    author        author_type  floor
# 0     Петербургская Строительная Компания          developer      1  \
# 1     Петербургская Строительная Компания          developer     13
# 2                                  GloraX          developer      5
# 3                           Группа Эталон          developer     13
# 4                                  GloraX          developer     11
# ...                                   ...                ...    ...
# 7113                                ДомИн  real_estate_agent     19
# 7114                          ID 85244212            unknown      7
# 7115                      Никита Лабецкий            realtor      4
# 7116               Константин Стародубцев            realtor     10
# 7117        CENTURY 21 Capital Petersburg  real_estate_agent      6
#
#       floors_count  rooms_count total_meters  price_per_m2     price
# 0                7          1.0         38.2        419999  16044000  \
# 1               25          1.0        36.81         33201   6706674
# 2               19          1.0        36.76        265777   9769999
# 3               18          1.0         32.6        303116   9881582
# 4               14          1.0        34.44        322009  11089999
# ...            ...          ...          ...           ...       ...
# 7113            19          0.5         22.0        231818   5099999
# 7114            19          0.5         27.0        168518   4550000
# 7115            25          0.5         24.7        182186   4499999
# 7116            14          0.5        25.91        189116   4900000
# 7117            27          0.5         24.8        181451   4500000
#
#      year_of_construction living_meters kitchen_meters           district
# 0                    2023          12.0           12.0      Petrogradskij  \
# 1                    2024          10.0           13.0         Primorskij
# 2                    2025          11.0           11.0   Vasileostrovskij
# 3                    2022          21.0           None     Admiraltejskij
# 4                    2024          12.0           13.0  Krasnogvardejskij
# ...                   ...           ...            ...                ...
# 7113                 2017          None            1.0   Vasileostrovskij
# 7114                 2017          None           None         Primorskij
# 7115                 2021          15.0            4.0         Primorskij
# 7116                 2022          None           19.0         Primorskij
# 7117                 2019          17.0           None         Vyborgskij
#
#                  street              underground
# 0           Chkalovskoe           Petrogradskaja  \
# 1             Kolomjagi  Prospekt Prosveschenija
# 2               Morskoj                    Zenit
# 3          Izmajlovskoe        Moskovskie vorota
# 4           Malaja Ohta              Ladozhskaja
# ...                 ...                      ...
# 7113            Morskoj              Primorskaja
# 7114      Parashjutnaja   Komendantskij prospekt
# 7115          Kolomjagi   Komendantskij prospekt
# 7116       Ozero Dolgoe   Komendantskij prospekt
# 7117  Nikolaja Rubtsova                   Parnas
#
#                        residential_complex    flat_id
# 0                         Severnaja Korona  284740225
# 1                               Frends ZhK  280819981
# 2     Gloraks Premium Vasileostrovskij ZhK  279507591
# 3                        Kvartal Galaktika  285017335
# 4                         Glorax Zanevskij  279351916
# ...                                    ...        ...
# 7113                                   NaN  285244128
# 7114                              Graffiti  283138090
# 7115                          Chistoe nebo  273083309
# 7116                          Chistoe nebo  272558236
# 7117                      Severnaja dolina  285359807
#
# [7117 rows x 16 columns]

# %% [markdown]
# ## EDA

# %%
data.describe(include=['int','float'])
# Out:
#              floor  floors_count  rooms_count  total_meters  price_per_m2
# count  7118.000000   7118.000000  7118.000000   7118.000000  7.118000e+03  \
# mean      6.021776     11.908401     2.270020     73.100469  2.420599e+05
# std       5.095265      6.884546     1.511374     54.837045  3.670186e+05
# min       1.000000      1.000000     0.500000     -1.000000 -7.150029e+06
# 25%       2.000000      6.000000     1.000000     33.260000  1.669048e+05
# 50%       4.000000     10.000000     2.000000     55.845000  2.061875e+05
# 75%       8.000000     16.000000     4.000000     98.000000  2.729540e+05
# max      34.000000    109.000000     5.000000    654.700000  2.835052e+07
#
#               price  year_of_construction  living_meters  kitchen_meters
# count  7.118000e+03           7118.000000    7118.000000     7118.000000
# mean   2.003049e+07           1950.194718      36.726861       12.124389
# std    3.192596e+07            295.113269      32.131965       11.195698
# min    1.750000e+06             -1.000000      -1.000000       -1.000000
# 25%    6.428277e+06           1972.000000      15.000000        5.000000
# 50%    1.136871e+07           2020.000000      26.600000       11.000000
# 75%    2.150000e+07           2023.000000      52.100000       17.000000
# max    1.200000e+09           2026.000000     450.000000      135.000000

# %%
data.describe(include=['O'])
# Out:
#                    author        author_type    district      street
# count                7096               7096        7118        6998  \
# unique               1142                  7          23         717
# top     ЛСР. Недвижимость  real_estate_agent  Primorskij  Petrovskij
# freq                  575               3769        1147         290
#
#                    underground residential_complex    flat_id
# count                     6757                4420       7118
# unique                      71                 548       7117
# top     Komendantskij prospekt      Tsvetnoj Gorod  275000896
# freq                       417                 142          2

# %%
developers_top10 = data['author'].value_counts()[:10]

# %%
plt.figure(figsize=(7,5))
sns.barplot(x = developers_top10.index, y =developers_top10)
plt.ylabel('Количество предложений на рынке')
plt.xlabel('Застройщик')
plt.xticks(rotation = 30,ha='right');
